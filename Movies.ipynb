# %% [markdown]
# # Do Tamil Movies have an impact on the alcoholism and substance usage in Tamil Nadu?

# %% [markdown]
# ### Functions for web scraping from IMDB using URLs

# %%
import requests
from bs4 import BeautifulSoup
import re
import string
import numpy as np

def url_alc_imdb(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    text = [p.text for p in soup.find('section', id = "advisory-alcohol")]
    req = text[3]
    req = re.sub('\[.*?\]', '', req)
    req = re.sub('[%s]' % re.escape(string.punctuation), '', req)
    req = re.sub('\s+', ' ', req)
    alc_cont = ''
    alc_cont = req.split(' ').pop(1)
    if(alc_cont == 'Be'):
        alc_cont = 'Unrated'
    
    #print(alc_cont)
    return alc_cont
    #return text

def unique(url):
    seen = set()
    seen_add = seen.add
    return [x for x in url if not (x in seen or seen_add(x))]

#unique(all_movie_links)

def get_URL_list(url):
    response = requests.get(url).text
    soup = BeautifulSoup(response, 'lxml')
    text = [link.get('href') for link in soup.find_all('a', 
                          attrs={'href': re.compile("^\/title\/[t]{2}[0-9]{4,10}\/$")})]
    preURL = 'https://www.imdb.com'
    postURL = 'parentalguide'
    url_list = []
    i=0
    for x in text:
        x = preURL + x + postURL
        url_list.append(x)
    #url_list = list(set(url_list))
    url_list = unique(url_list)
    print(url_list)
    return url_list


        
def get_movie_title_list(url):
    response = requests.get(url).text
    soup = BeautifulSoup(response, 'lxml')  
    title_list = [link.text for link in soup.find_all('a', attrs={'href': re.compile("^\/title")})]
    
    for x in title_list:
        if(x==' \n'):
            title_list.remove(' \n')
    for x in title_list:      
        if(x=='See full summary'):
            title_list.remove('See full summary')
    print(title_list)
        
            
    #print(text)
    return title_list

#URL OF TOP TAMIL MOVIES LIST
movie_list_2015_url = 'https://www.imdb.com/list/ls031392332/'
movie_list_2016_url = 'https://www.imdb.com/list/ls064266039/'
movie_list_2017_url = 'https://www.imdb.com/list/ls069242710/'
movie_list_2018_url = 'https://www.imdb.com/list/ls045861940/'
movie_list_2019_url = 'https://www.imdb.com/list/ls041663030/'
movie_list_2020_url = 'https://www.imdb.com/list/ls097124558/'
movie_list_2021_url = 'https://www.imdb.com/list/ls084663427/'

#movie_urls_list = ['https://www.imdb.com/list/ls031392332/', 'https://www.imdb.com/list/ls064266039/','https://www.imdb.com/list/ls069242710/', 'https://www.imdb.com/list/ls045861940/','https://www.imdb.com/list/ls041663030/', 'https://www.imdb.com/list/ls097124558/','https://www.imdb.com/list/ls084663427/']

# movie_titles = []
# movie_urls = []
# movie_urls = [get_URL_list(u) for u in movie_urls]
# movie_titles = [get_movie_title_list(u) for u in movie_urls]

# %% [markdown]
# ### Top Tamil Movies list for each year from IMDB

# %%
#GETTING EACH YEARS DETAILS IN THE FORM OF A LIST
print("**2015 MOVIES**")
u1 = get_URL_list(movie_list_2015_url)
t1 = get_movie_title_list(movie_list_2015_url)
#print(u1)
#print(t1)
print("**2016 MOVIES**")
u2 = get_URL_list(movie_list_2016_url)
t2 = get_movie_title_list(movie_list_2016_url)

print("**2017 MOVIES**")
u3 = get_URL_list(movie_list_2017_url)
t3 = get_movie_title_list(movie_list_2017_url)

print("**2018 MOVIES**")
u4 = get_URL_list(movie_list_2018_url)
t4 = get_movie_title_list(movie_list_2018_url)

print("**2019 MOVIES**")
u5 = get_URL_list(movie_list_2019_url)
t5 = get_movie_title_list(movie_list_2019_url)

print("**2020 MOVIES**")
u6 = get_URL_list(movie_list_2020_url)
t6 = get_movie_title_list(movie_list_2020_url)

print("**2021 MOVIES**")
u7 = get_URL_list(movie_list_2021_url)
t7 = get_movie_title_list(movie_list_2021_url)
# Out:
# **2015 MOVIES**
# ['https://www.imdb.com/title/tt3973410/parentalguide', 'https://www.imdb.com/title/tt2631186/parentalguide', 'https://www.imdb.com/title/tt4429128/parentalguide', 'https://www.imdb.com/title/tt4987556/parentalguide', 'https://www.imdb.com/title/tt4112208/parentalguide', 'https://www.imdb.com/title/tt4684258/parentalguide', 'https://www.imdb.com/title/tt4806232/parentalguide', 'https://www.imdb.com/title/tt5090220/parentalguide', 'https://www.imdb.com/title/tt4446348/parentalguide', 'https://www.imdb.com/title/tt4701688/parentalguide', 'https://www.imdb.com/title/tt4446318/parentalguide', 'https://www.imdb.com/title/tt4937812/parentalguide', 'https://www.imdb.com/title/tt2002868/parentalguide', 'https://www.imdb.com/title/tt5178278/parentalguide', 'https://www.imdb.com/title/tt5037912/parentalguide']
# ['Kaakkaa Muttai', 'Bãhubali: The Beginning', 'Papanasam', 'Thani Oruvan', 'Kuttram Kadithal', '36 Vayadhinile', 'Indru Netru Naalai', 'Kirumi', 'Purampokku', 'Demonte Colony', 'Rajathandhiram', 'Thoongaavanam', 'Anegan', 'Vedalam', 'Maya']
# **2016 MOVIES**
# ['https://www.imdb.com/title/tt4991384/parentalguide', 'https://www.imdb.com/title/tt6380520/parentalguide', 'https://www.imdb.com/title/tt5310090/parentalguide', 'https://www.imdb.com/title/tt6076366/parentalguide', 'https://www.imdb.com/title/tt5200962/parentalguide', 'https://www.imdb.com/title/tt5039054/parentalguide', 'https://www.imdb.com/title/tt5477194/parentalguide', 'https://www.imdb.com/title/tt5857968/parentalguide', 'https://www.imdb.com/title/tt5611648/parentalguide', 'https://www.imdb.com/title/tt4981966/parentalguide', 'https://www.imdb.com/title/tt5071886/parentalguide', 'https://www.imdb.com/title/tt5556784/parentalguide', 'https://www.imdb.com/title/tt2401585/parentalguide', 'https://www.imdb.com/title/tt5523174/parentalguide', 'https://www.imdb.com/title/tt5491920/parentalguide', 'https://www.imdb.com/title/tt5500416/parentalguide', 'https://www.imdb.com/title/tt6317052/parentalguide', 'https://www.imdb.com/title/tt4741412/parentalguide', 'https://www.imdb.com/title/tt5440700/parentalguide', 'https://www.imdb.com/title/tt6126294/parentalguide', 'https://www.imdb.com/title/tt5335394/parentalguide', 'https://www.imdb.com/title/tt6286666/parentalguide', 'https://www.imdb.com/title/tt5455344/parentalguide', 'https://www.imdb.com/title/tt5372466/parentalguide', 'https://www.imdb.com/title/tt5459644/parentalguide']
# ['Visaaranai', 'Dhuruvangal Pathinaaru', 'Saala Khadoos', 'Aandavan Kattalai', 'Kadhalum Kadanthu Pogum', 'Oopiri', 'Iraivi', 'Kuttrame Thandanai', 'Joker', '24', 'Kabali', 'Kodi', 'Achcham Yenbadhu Madamaiyada', 'Pichaikkaran', 'Sethupathi', 'Kanithan', 'Chennai 600028 II: Second Innings', 'Uriyadi', 'Theri', 'Remo', 'Kathakali', 'Saithan', 'Miruthan', 'Iru Mugan', 'Jil Jung Juk']
# **2017 MOVIES**
# ['https://www.imdb.com/title/tt5867800/parentalguide', 'https://www.imdb.com/title/tt7060460/parentalguide', 'https://www.imdb.com/title/tt6148156/parentalguide', 'https://www.imdb.com/title/tt5559528/parentalguide', 'https://www.imdb.com/title/tt6734886/parentalguide', 'https://www.imdb.com/title/tt7190460/parentalguide', 'https://www.imdb.com/title/tt7531040/parentalguide', 'https://www.imdb.com/title/tt6299040/parentalguide', 'https://www.imdb.com/title/tt7257586/parentalguide', 'https://www.imdb.com/title/tt7019820/parentalguide', 'https://www.imdb.com/title/tt6270936/parentalguide', 'https://www.imdb.com/title/tt6594758/parentalguide', 'https://www.imdb.com/title/tt6998574/parentalguide', 'https://www.imdb.com/title/tt7010156/parentalguide', 'https://www.imdb.com/title/tt6998596/parentalguide', 'https://www.imdb.com/title/tt4328934/parentalguide', 'https://www.imdb.com/title/tt7161122/parentalguide', 'https://www.imdb.com/title/tt4818776/parentalguide', 'https://www.imdb.com/title/tt4849438/parentalguide', 'https://www.imdb.com/title/tt6747242/parentalguide', 'https://www.imdb.com/title/tt6237984/parentalguide', 'https://www.imdb.com/title/tt6642814/parentalguide']
# ['Aruvi', 'Theeran Adhigaaram Ondru', 'Vikram Vedha', 'Maanagaram', 'Power Paandi', 'Thupparivaalan', 'Meyaadha Maan', 'The Ghazi Attack', 'Kurangu Bommai', 'Velaikkaran', 'Aramm', 'Kuttram 23', 'Oru Kidayin Karunai Manu', 'Maragadha Naanayam', 'Rangoon', 'Taramani', 'Meesaya murukku', 'Lens', 'Baahubali 2: The Conclusion', '8 Thottakkal', 'Magalir Mattum', 'Kadugu']
# **2018 MOVIES**
# ['https://www.imdb.com/title/tt5959980/parentalguide', 'https://www.imdb.com/title/tt8176054/parentalguide', 'https://www.imdb.com/title/tt7019842/parentalguide', 'https://www.imdb.com/title/tt7060344/parentalguide', 'https://www.imdb.com/title/tt7794052/parentalguide', 'https://www.imdb.com/title/tt7179784/parentalguide', 'https://www.imdb.com/title/tt7892050/parentalguide', 'https://www.imdb.com/title/tt6186910/parentalguide', 'https://www.imdb.com/title/tt7986222/parentalguide', 'https://www.imdb.com/title/tt8011324/parentalguide', 'https://www.imdb.com/title/tt5080556/parentalguide', 'https://www.imdb.com/title/tt8458718/parentalguide', 'https://www.imdb.com/title/tt6929642/parentalguide', 'https://www.imdb.com/title/tt7179714/parentalguide', 'https://www.imdb.com/title/tt8364418/parentalguide', 'https://www.imdb.com/title/tt7943040/parentalguide', 'https://www.imdb.com/title/tt7738594/parentalguide', 'https://www.imdb.com/title/tt8733898/parentalguide', 'https://www.imdb.com/title/tt8208098/parentalguide', 'https://www.imdb.com/title/tt6237966/parentalguide']
# ['Vada Chennai', 'Pariyerum Perumal', '96', 'Ratsasan', 'Merku Thodarchi Malai', 'Irumbu Thirai', 'Chekka Chivantha Vaanam', 'Imaikkaa Nodigal', 'Kolamavu Kokila', 'Seethakaathi', '2.0', 'Kanaa', 'Kaala', 'Iravukku Aayiram Kangal', 'Adanga Maru', 'Savarakathi', 'Naachiyar', 'U-Turn', 'Pyaar Prema Kaadhal', 'Thaanaa Serndha Koottam']
# **2019 MOVIES**
# ['https://www.imdb.com/title/tt7738784/parentalguide', 'https://www.imdb.com/title/tt7019942/parentalguide', 'https://www.imdb.com/title/tt9477520/parentalguide', 'https://www.imdb.com/title/tt9900782/parentalguide', 'https://www.imdb.com/title/tt10370116/parentalguide', 'https://www.imdb.com/title/tt8747560/parentalguide', 'https://www.imdb.com/title/tt9614988/parentalguide', 'https://www.imdb.com/title/tt10370932/parentalguide', 'https://www.imdb.com/title/tt9675716/parentalguide', 'https://www.imdb.com/title/tt10996896/parentalguide', 'https://www.imdb.com/title/tt10556036/parentalguide', 'https://www.imdb.com/title/tt6982254/parentalguide', 'https://www.imdb.com/title/tt7822438/parentalguide', 'https://www.imdb.com/title/tt8959820/parentalguide', 'https://www.imdb.com/title/tt8914492/parentalguide', 'https://www.imdb.com/title/tt8042132/parentalguide', 'https://www.imdb.com/title/tt9109794/parentalguide', 'https://www.imdb.com/title/tt10055770/parentalguide']
# ['Peranbu', 'Super Deluxe', 'Asuran', 'Kaithi', 'Oththa Seruppu Size 7', 'KD', 'Sillu Karuppatti', 'Magamuni', 'Nerkonda Paarvai', 'Irandam Ulagaporin Kadaisi Gundu', 'Jiivi', 'To Let', 'Thadam', 'Petta', 'Game Over', 'Kaalidas', 'Kolaigaran', 'Vellaipookal']
# **2020 MOVIES**
# ['https://www.imdb.com/title/tt9635540/parentalguide', 'https://www.imdb.com/title/tt10189514/parentalguide', 'https://www.imdb.com/title/tt10594792/parentalguide', 'https://www.imdb.com/title/tt13206988/parentalguide', 'https://www.imdb.com/title/tt9109976/parentalguide', 'https://www.imdb.com/title/tt10750020/parentalguide', 'https://www.imdb.com/title/tt11731768/parentalguide', 'https://www.imdb.com/title/tt11143108/parentalguide', 'https://www.imdb.com/title/tt8333788/parentalguide', 'https://www.imdb.com/title/tt11138290/parentalguide', 'https://www.imdb.com/title/tt11318228/parentalguide', 'https://www.imdb.com/title/tt7247410/parentalguide', 'https://www.imdb.com/title/tt10295430/parentalguide', 'https://www.imdb.com/title/tt10966832/parentalguide', 'https://www.imdb.com/title/tt7087984/parentalguide', 'https://www.imdb.com/title/tt11617442/parentalguide', 'https://www.imdb.com/title/tt9110340/parentalguide', 'https://www.imdb.com/title/tt11731984/parentalguide', 'https://www.imdb.com/title/tt9605894/parentalguide', 'https://www.imdb.com/title/tt11199310/parentalguide', 'https://www.imdb.com/title/tt13087958/parentalguide', 'https://www.imdb.com/title/tt11581264/parentalguide', 'https://www.imdb.com/title/tt8042292/parentalguide', 'https://www.imdb.com/title/tt8011344/parentalguide', 'https://www.imdb.com/title/tt11772576/parentalguide']
# ['Darbar', 'Soorarai Pottru', 'Mafia', 'Paava Kadhaigal', 'Psycho', 'Pattas', 'Ka Pae Ranasingam', 'Oh My Kadavule', 'Rajavukku Check', 'Naan Sirithaal', 'Vaanam Kottattum', 'Thatrom Thookrom', 'Paramapadham Vilayattu', 'Dagaalty', 'Vaanam Kottattum', 'Server Sundaram', 'Day knight', 'Andhaghaaram', 'Dharala Prabhu', 'Nishabdham', 'Miss India', 'Putham Pudhu Kaalai', 'Draupathi', 'Kannum Kannum Kollaiyadithaal', 'Asura Guru', 'Biscoth']
# **2021 MOVIES**
# ['https://www.imdb.com/title/tt11580854/parentalguide', 'https://www.imdb.com/title/tt10687070/parentalguide', 'https://www.imdb.com/title/tt11581174/parentalguide', 'https://www.imdb.com/title/tt15097216/parentalguide', 'https://www.imdb.com/title/tt7822758/parentalguide', 'https://www.imdb.com/title/tt14095634/parentalguide', 'https://www.imdb.com/title/tt10579952/parentalguide', 'https://www.imdb.com/title/tt11374902/parentalguide', 'https://www.imdb.com/title/tt11803618/parentalguide', 'https://www.imdb.com/title/tt4983780/parentalguide', 'https://www.imdb.com/title/tt11991132/parentalguide', 'https://www.imdb.com/title/tt12299714/parentalguide', 'https://www.imdb.com/title/tt9319874/parentalguide', 'https://www.imdb.com/title/tt10275546/parentalguide', 'https://www.imdb.com/title/tt11640022/parentalguide', 'https://www.imdb.com/title/tt14092076/parentalguide', 'https://www.imdb.com/title/tt10888824/parentalguide', 'https://www.imdb.com/title/tt5985720/parentalguide', 'https://www.imdb.com/title/tt13451738/parentalguide', 'https://www.imdb.com/title/tt13885642/parentalguide']
# ['Sarpatta Parambarai', 'Mandela', 'Karnan', 'Jai Bhim', 'Kaadan', 'Thaen', 'Master', 'Doctor', 'C/O Kaadhal', 'Maanaadu', 'Kamali from Nadukkaveri', 'Thittam Irandu', 'Maara', 'Aelay', 'Chakra', 'Anbirkiniyal', 'Teddy', 'Nenjam Marappathillai', 'Kodiyil Oruvan', 'Sabhaapathy']

# %% [markdown]
# ### Concatenating the lists of URLs and Movie Titles

# %%
all_movie_titles = []
all_movie_links = []
all_movie_titles = t1 + t2 + t3 + t4 + t5 + t6 + t7
all_movie_links = u1 + u2 + u3 + u4 + u5 + u6 + u7
# all_movie_titles.remove('Server Sundaram')
# all_movie_links.remove('https://www.imdb.com/title/tt7087984/parentalguide')
print(all_movie_titles)
print(all_movie_links)
# Out:
# ['Kaakkaa Muttai', 'Bãhubali: The Beginning', 'Papanasam', 'Thani Oruvan', 'Kuttram Kadithal', '36 Vayadhinile', 'Indru Netru Naalai', 'Kirumi', 'Purampokku', 'Demonte Colony', 'Rajathandhiram', 'Thoongaavanam', 'Anegan', 'Vedalam', 'Maya', 'Visaaranai', 'Dhuruvangal Pathinaaru', 'Saala Khadoos', 'Aandavan Kattalai', 'Kadhalum Kadanthu Pogum', 'Oopiri', 'Iraivi', 'Kuttrame Thandanai', 'Joker', '24', 'Kabali', 'Kodi', 'Achcham Yenbadhu Madamaiyada', 'Pichaikkaran', 'Sethupathi', 'Kanithan', 'Chennai 600028 II: Second Innings', 'Uriyadi', 'Theri', 'Remo', 'Kathakali', 'Saithan', 'Miruthan', 'Iru Mugan', 'Jil Jung Juk', 'Aruvi', 'Theeran Adhigaaram Ondru', 'Vikram Vedha', 'Maanagaram', 'Power Paandi', 'Thupparivaalan', 'Meyaadha Maan', 'The Ghazi Attack', 'Kurangu Bommai', 'Velaikkaran', 'Aramm', 'Kuttram 23', 'Oru Kidayin Karunai Manu', 'Maragadha Naanayam', 'Rangoon', 'Taramani', 'Meesaya murukku', 'Lens', 'Baahubali 2: The Conclusion', '8 Thottakkal', 'Magalir Mattum', 'Kadugu', 'Vada Chennai', 'Pariyerum Perumal', '96', 'Ratsasan', 'Merku Thodarchi Malai', 'Irumbu Thirai', 'Chekka Chivantha Vaanam', 'Imaikkaa Nodigal', 'Kolamavu Kokila', 'Seethakaathi', '2.0', 'Kanaa', 'Kaala', 'Iravukku Aayiram Kangal', 'Adanga Maru', 'Savarakathi', 'Naachiyar', 'U-Turn', 'Pyaar Prema Kaadhal', 'Thaanaa Serndha Koottam', 'Peranbu', 'Super Deluxe', 'Asuran', 'Kaithi', 'Oththa Seruppu Size 7', 'KD', 'Sillu Karuppatti', 'Magamuni', 'Nerkonda Paarvai', 'Irandam Ulagaporin Kadaisi Gundu', 'Jiivi', 'To Let', 'Thadam', 'Petta', 'Game Over', 'Kaalidas', 'Kolaigaran', 'Vellaipookal', 'Darbar', 'Soorarai Pottru', 'Mafia', 'Paava Kadhaigal', 'Psycho', 'Pattas', 'Ka Pae Ranasingam', 'Oh My Kadavule', 'Rajavukku Check', 'Naan Sirithaal', 'Vaanam Kottattum', 'Thatrom Thookrom', 'Paramapadham Vilayattu', 'Dagaalty', 'Vaanam Kottattum', 'Server Sundaram', 'Day knight', 'Andhaghaaram', 'Dharala Prabhu', 'Nishabdham', 'Miss India', 'Putham Pudhu Kaalai', 'Draupathi', 'Kannum Kannum Kollaiyadithaal', 'Asura Guru', 'Biscoth', 'Sarpatta Parambarai', 'Mandela', 'Karnan', 'Jai Bhim', 'Kaadan', 'Thaen', 'Master', 'Doctor', 'C/O Kaadhal', 'Maanaadu', 'Kamali from Nadukkaveri', 'Thittam Irandu', 'Maara', 'Aelay', 'Chakra', 'Anbirkiniyal', 'Teddy', 'Nenjam Marappathillai', 'Kodiyil Oruvan', 'Sabhaapathy']
# ['https://www.imdb.com/title/tt3973410/parentalguide', 'https://www.imdb.com/title/tt2631186/parentalguide', 'https://www.imdb.com/title/tt4429128/parentalguide', 'https://www.imdb.com/title/tt4987556/parentalguide', 'https://www.imdb.com/title/tt4112208/parentalguide', 'https://www.imdb.com/title/tt4684258/parentalguide', 'https://www.imdb.com/title/tt4806232/parentalguide', 'https://www.imdb.com/title/tt5090220/parentalguide', 'https://www.imdb.com/title/tt4446348/parentalguide', 'https://www.imdb.com/title/tt4701688/parentalguide', 'https://www.imdb.com/title/tt4446318/parentalguide', 'https://www.imdb.com/title/tt4937812/parentalguide', 'https://www.imdb.com/title/tt2002868/parentalguide', 'https://www.imdb.com/title/tt5178278/parentalguide', 'https://www.imdb.com/title/tt5037912/parentalguide', 'https://www.imdb.com/title/tt4991384/parentalguide', 'https://www.imdb.com/title/tt6380520/parentalguide', 'https://www.imdb.com/title/tt5310090/parentalguide', 'https://www.imdb.com/title/tt6076366/parentalguide', 'https://www.imdb.com/title/tt5200962/parentalguide', 'https://www.imdb.com/title/tt5039054/parentalguide', 'https://www.imdb.com/title/tt5477194/parentalguide', 'https://www.imdb.com/title/tt5857968/parentalguide', 'https://www.imdb.com/title/tt5611648/parentalguide', 'https://www.imdb.com/title/tt4981966/parentalguide', 'https://www.imdb.com/title/tt5071886/parentalguide', 'https://www.imdb.com/title/tt5556784/parentalguide', 'https://www.imdb.com/title/tt2401585/parentalguide', 'https://www.imdb.com/title/tt5523174/parentalguide', 'https://www.imdb.com/title/tt5491920/parentalguide', 'https://www.imdb.com/title/tt5500416/parentalguide', 'https://www.imdb.com/title/tt6317052/parentalguide', 'https://www.imdb.com/title/tt4741412/parentalguide', 'https://www.imdb.com/title/tt5440700/parentalguide', 'https://www.imdb.com/title/tt6126294/parentalguide', 'https://www.imdb.com/title/tt5335394/parentalguide', 'https://www.imdb.com/title/tt6286666/parentalguide', 'https://www.imdb.com/title/tt5455344/parentalguide', 'https://www.imdb.com/title/tt5372466/parentalguide', 'https://www.imdb.com/title/tt5459644/parentalguide', 'https://www.imdb.com/title/tt5867800/parentalguide', 'https://www.imdb.com/title/tt7060460/parentalguide', 'https://www.imdb.com/title/tt6148156/parentalguide', 'https://www.imdb.com/title/tt5559528/parentalguide', 'https://www.imdb.com/title/tt6734886/parentalguide', 'https://www.imdb.com/title/tt7190460/parentalguide', 'https://www.imdb.com/title/tt7531040/parentalguide', 'https://www.imdb.com/title/tt6299040/parentalguide', 'https://www.imdb.com/title/tt7257586/parentalguide', 'https://www.imdb.com/title/tt7019820/parentalguide', 'https://www.imdb.com/title/tt6270936/parentalguide', 'https://www.imdb.com/title/tt6594758/parentalguide', 'https://www.imdb.com/title/tt6998574/parentalguide', 'https://www.imdb.com/title/tt7010156/parentalguide', 'https://www.imdb.com/title/tt6998596/parentalguide', 'https://www.imdb.com/title/tt4328934/parentalguide', 'https://www.imdb.com/title/tt7161122/parentalguide', 'https://www.imdb.com/title/tt4818776/parentalguide', 'https://www.imdb.com/title/tt4849438/parentalguide', 'https://www.imdb.com/title/tt6747242/parentalguide', 'https://www.imdb.com/title/tt6237984/parentalguide', 'https://www.imdb.com/title/tt6642814/parentalguide', 'https://www.imdb.com/title/tt5959980/parentalguide', 'https://www.imdb.com/title/tt8176054/parentalguide', 'https://www.imdb.com/title/tt7019842/parentalguide', 'https://www.imdb.com/title/tt7060344/parentalguide', 'https://www.imdb.com/title/tt7794052/parentalguide', 'https://www.imdb.com/title/tt7179784/parentalguide', 'https://www.imdb.com/title/tt7892050/parentalguide', 'https://www.imdb.com/title/tt6186910/parentalguide', 'https://www.imdb.com/title/tt7986222/parentalguide', 'https://www.imdb.com/title/tt8011324/parentalguide', 'https://www.imdb.com/title/tt5080556/parentalguide', 'https://www.imdb.com/title/tt8458718/parentalguide', 'ht ...

# %% [markdown]
# ### Finding the alcohol content display severity by calling the url_alc_imdb(url) function

# %%
alc_content_movie = []
for x in all_movie_links:
    alc_content_movie.append(url_alc_imdb(x))
print(alc_content_movie)
# Out:
# ['None', 'Mild', 'None', 'Moderate', 'None', 'Unrated', 'Mild', 'Unrated', 'Unrated', 'Moderate', 'Unrated', 'Moderate', 'Moderate', 'Moderate', 'Unrated', 'Mild', 'Mild', 'None', 'None', 'Moderate', 'Moderate', 'Severe', 'Mild', 'Unrated', 'None', 'Moderate', 'Mild', 'Unrated', 'Unrated', 'Mild', 'Unrated', 'Moderate', 'Severe', 'Mild', 'Moderate', 'Mild', 'Moderate', 'Severe', 'Moderate', 'Severe', 'Mild', 'Mild', 'Moderate', 'Unrated', 'Moderate', 'Mild', 'Unrated', 'None', 'Unrated', 'Mild', 'Mild', 'Moderate', 'Unrated', 'Mild', 'Unrated', 'Mild', 'Unrated', 'Unrated', 'Mild', 'Mild', 'Unrated', 'Unrated', 'Moderate', 'Moderate', 'None', 'Mild', 'Unrated', 'Moderate', 'Mild', 'Mild', 'Moderate', 'Mild', 'None', 'None', 'Severe', 'Unrated', 'Moderate', 'Unrated', 'Mild', 'Mild', 'Moderate', 'None', 'None', 'Mild', 'Mild', 'Severe', 'Mild', 'Mild', 'Mild', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Mild', 'Moderate', 'Mild', 'None', 'Mild', 'Mild', 'Moderate', 'Mild', 'None', 'Severe', 'None', 'Mild', 'Mild', 'None', 'Moderate', 'Moderate', 'Mild', 'Moderate', 'Moderate', 'Unrated', 'Mild', '', 'Mild', 'Moderate', 'Mild', 'Moderate', 'Mild', 'Mild', 'Mild', 'Mild', 'Mild', 'None', 'Moderate', 'Mild', 'Mild', 'Mild', 'Unrated', 'Unrated', 'Moderate', 'None', 'Unrated', 'Mild', 'Unrated', 'Unrated', 'Unrated', 'Moderate', 'Unrated', 'Unrated', 'Mild', 'Moderate', 'Unrated', 'Unrated']

# %% [markdown]
# ### Creating dataframes and saving to CSV file locally

# %%
import pandas as pd


dict = {'Movie Name':all_movie_titles, 'IMDB Link':all_movie_links, 'Alcoholism Displayed':alc_content_movie}
df1 = pd.DataFrame({'Movie Name':all_movie_titles})
df2 = pd.DataFrame({'IMDB Link':all_movie_links})
df3 = pd.DataFrame({'Alcoholism Displayed':alc_content_movie})

df = [df1, df2, df3]

df_final = pd.concat(df, axis=1)
df_final.to_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\movies_alc.csv', index=False)

# %%
(pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\movies_alc.csv'))
one = df_final[df_final['Alcoholism Displayed'] == 'Severe'].count()
two = df_final[df_final['Alcoholism Displayed'] == 'Moderate'].count()
three = df_final[df_final['Alcoholism Displayed'] == 'Mild'].count()
four = df_final[df_final['Alcoholism Displayed'] == 'Unrated'].count()
print(one)
print(two)
print(three)
print(four)
# Out:
# Movie Name              7
# IMDB Link               7
# Alcoholism Displayed    7
# dtype: int64
# Movie Name              37
# IMDB Link               37
# Alcoholism Displayed    37
# dtype: int64
# Movie Name              50
# IMDB Link               50
# Alcoholism Displayed    50
# dtype: int64
# Movie Name              32
# IMDB Link               32
# Alcoholism Displayed    32
# dtype: int64

# %% [markdown]
# ### Mapping each movie to the year of release

# %%
from itertools import repeat
def mov_year(url, year):
    url_c = len(url)
    #print(url_c)
    movie_year = []
    movie_year.extend(repeat(year,url_c))
    return (movie_year)
movie_years_list = mov_year(u1, '2015') + mov_year(u2, '2016') + mov_year(u3, '2017')+ mov_year(u4, '2018') + mov_year(u5, '2019') + mov_year(u6, '2020') + mov_year(u7, '2021')
print(movie_years_list)
# Out:
# ['2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021', '2021']

# %% [markdown]
# ### Creating the final dataset after creating and cleaning

# %%
import pandas as pd


dict = {'Movie Name':all_movie_titles, 'IMDB Link':all_movie_links, 'Alcoholism Displayed':alc_content_movie, 'Year of Release':movie_years_list}
df1 = pd.DataFrame({'Movie Name':all_movie_titles})
df2 = pd.DataFrame({'IMDB Link':all_movie_links})
df3 = pd.DataFrame({'Alcoholism Displayed':alc_content_movie})
df4 = pd.DataFrame({'Year of Release': movie_years_list})

df = [df1, df2, df3, df4]

df_final = pd.concat(df, axis=1)
df_final.to_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\movies_alc.csv', index=False)

# %%
(pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\movies_alc.csv'))
# Out:
#                   Movie Name  \
# 0             Kaakkaa Muttai
# 1    Bãhubali: The Beginning
# 2                  Papanasam
# 3               Thani Oruvan
# 4           Kuttram Kadithal
# ..                       ...
# 141             Anbirkiniyal
# 142                    Teddy
# 143    Nenjam Marappathillai
# 144           Kodiyil Oruvan
# 145              Sabhaapathy
#
#                                              IMDB Link Alcoholism Displayed  \
# 0    https://www.imdb.com/title/tt3973410/parentalg...                 None
# 1    https://www.imdb.com/title/tt2631186/parentalg...                 Mild
# 2    https://www.imdb.com/title/tt4429128/parentalg...                 None
# 3    https://www.imdb.com/title/tt4987556/parentalg...             Moderate
# 4    https://www.imdb.com/title/tt4112208/parentalg...                 None
# ..                                                 ...                  ...
# 141  https://www.imdb.com/title/tt14092076/parental...              Unrated
# 142  https://www.imdb.com/title/tt10888824/parental...                 Mild
# 143  https://www.imdb.com/title/tt5985720/parentalg...             Moderate
# 144  https://www.imdb.com/title/tt13451738/parental...              Unrated
# 145  https://www.imdb.com/title/tt13885642/parental...              Unrated
#
#      Year of Release
# 0               2015
# 1               2015
# 2               2015
# 3               2015
# 4               2015
# ..               ...
# 141             2021
# 142             2021
# 143             2021
# 144             2021
# 145             2021
#
# [146 rows x 4 columns]

# %% [markdown]
# ### Webscrape the alcohol revenue in Tamil Nadu to find out how much is consumed<br><br>Fetched from wikipedia

# %%
import requests
from bs4 import BeautifulSoup
import re
import string
import numpy as np
import pandas as pd
url = 'https://en.wikipedia.org/wiki/TASMAC'
page = requests.get(url).text
soup = BeautifulSoup(page, "lxml")

def getTable(url):
    rows = []
    for child in soup.find_all('tbody')[1].children:
        row = []
        for td in child:
            try:
                row.append(td.text.replace('\n', ''))
            except:
                continue
        if len(row) > 0:
            rows.append(row)

    df = pd.DataFrame(rows[1:], columns=rows[0])
    df.to_csv(r'alc_tn', index=False)
    print('saved')
    return df

getTable(url)
# Out:
# saved
#      Fiscal Year   Revenue in Crores (₹)   % Change
# 0        2002–03                2,828.09
# 1        2003–04                   3,639     28.67%
# 2        2004–05                   4,872     33.88%
# 3        2005–06                6,086.95     24.94%
# 4        2006–07                   7,300     19.93%
# 5        2007–08                   8,822     20.85%
# 6        2008–09                10,601.5     20.17%
# 7        2009–10                  12,491     17.82%
# 8        2010–11               14,965.42     19.80%
# 9        2011–12               18,081.16     20.82%
# 10       2012–13               21,680.67     19.91%
# 11       2013–14                  23,401      7.93%
# 12       2014–15                  26,188     11.91%
# 13       2015–16              25,845.58      −6.76%
# 14       2016–17              26,995.25       6.97%
# 15       2017–18              26,797.96      −0.73%
# 16       2018–19               31,157.83      8.39%

# %%
dict_crime = {'2016':467369, '2017':420876, '2018':499188, '2019':455094
    
}


import requests
from bs4 import BeautifulSoup
import re
import string
import numpy as np
import pandas as pd
url = 'https://en.wikipedia.org/wiki/Crime_in_India'
page = requests.get(url).text
soup = BeautifulSoup(page, "lxml")

def get1Table(url):
    rows = []
    for child in soup.find_all('tbody')[1].children:
        row = []
        for td in child:
            try:
                row.append(td.text.replace('\n', ''))
            except:
                continue
        if len(row) > 0:
            rows.append(row)

    df = pd.DataFrame(rows[1:], columns=rows[0])
    return df

df1 = get1Table(url)
df2 = (df1[df1['State/UT'] == 'Tamil Nadu'])
df_crime = df2.T 
print(df_crime)
#df3 = df2['2016', '2017', '2018', '2019']
#print(df3)
df2.head(5)
# Out:
#                                              24
#
# State/UT                             Tamil Nadu
#
# 2016                                     467369
#
# 2017                                     420876
#
# 2018                                     499188
#
# 2019                                     455094
#
# Percentage share of state/UT (2019)         8.8
#
# Crime rate in 2019 (IPC+SLL crimes)       600.3
#         State/UT      2016      2017      2018      2019    \
# 24    Tamil Nadu    467369    420876    499188    455094
#
#    Percentage share of state/UT (2019)   Crime rate in 2019 (IPC+SLL crimes)
# 24                                 8.8                                 600.3

# %%
df_crime.to_csv(r'crime_tn.csv', index=False)

# %%
#transposing and displaying + adding data for missing years from govt portals
pd.read_csv(r'crime_tn.csv')
df_crime =pd.read_csv(r'crime_tn.csv')
df_crime.head(7)
# Out:
#    Year   Crime
# 0  2015  254604
# 1  2016  467369
# 2  2017  420876
# 3  2018  499188
# 4  2019  455094
# 5  2020  377681
# 6  2021       0

# %% [markdown]
# ### Appending the data to CSV

# %%
#manually inserting 2019-2020 and 2020-2021 from
#https://www.business-standard.com/article/economy-policy/tamil-nadu-earned-rs-33-811-crore-revenue-from-liquor-sales-121090700965_1.html
new_data = {
    'Fiscal Year': ['2019–20', '2020–21'],
    'Revenue in Crores (₹)	': ['33,811.14','33,133.24'],
    '% Change': ['8.51%', '−2.00%']
}
df = pd.DataFrame(new_data)
df.to_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\alc_tn.csv', mode='a', index=False, header=False)
print("Data appended successfully.")
# Out:
# Data appended successfully.

# %% [markdown]
# ### Data Cleaning

# %%
df = pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\alc_tn.csv')
def year_modify(x):
    x = x.split('–',1)
    x = x.pop(0)
    y = int(x)
    y = y+1
    print(y)
    return y

df['Fiscal Year'] = df['Fiscal Year'].apply(year_modify)
# Out:
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
df.head()
df.to_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\alc_tn_dataset.csv')
pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\alc_tn_dataset.csv')
# Out:
#     Unnamed: 0  Fiscal Year Revenue in Crores % Change
# 0            0         2003          2,828.09        -
# 1            1         2004             3,639   28.67%
# 2            2         2005             4,872   33.88%
# 3            3         2006          6,086.95   24.94%
# 4            4         2007             7,300   19.93%
# 5            5         2008             8,822   20.85%
# 6            6         2009         10,601.50   20.17%
# 7            7         2010            12,491   17.82%
# 8            8         2011         14,965.42   19.80%
# 9            9         2012         18,081.16   20.82%
# 10          10         2013         21,680.67   19.91%
# 11          11         2014            23,401    7.93%
# 12          12         2015            26,188   11.91%
# 13          13         2016         25,845.58   −6.76%
# 14          14         2017         26,995.25    6.97%
# 15          15         2018         26,797.96   −0.73%
# 16          16         2019         31,157.83    8.39%
# 17          17         2020         33,811.14    8.51%
# 18          18         2021         33,133.24   −2.00%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

g1 = pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\movies_alc.csv')
g2 = pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\alc_tn_dataset.csv')
print('New dataframes created')
# Out:
# New dataframes created

# %%
#only require 2015 onwards for alcohol data
#new dataframe with 2015-2021 alchol data
g2 = g2.iloc[12:]
print(g2)
#remove unrated movies
g1 = (g1[g1['Alcoholism Displayed'] != 'Unrated'])
g1.head()
# Out:
#     Unnamed: 0  Fiscal Year Revenue in Crores % Change
# 12          12         2015            26,188   11.91%
# 13          13         2016         25,845.58   −6.76%
# 14          14         2017         26,995.25    6.97%
# 15          15         2018         26,797.96   −0.73%
# 16          16         2019         31,157.83    8.39%
# 17          17         2020         33,811.14    8.51%
# 18          18         2021         33,133.24   −2.00%
#                 Movie Name                                          IMDB Link  \
# 0           Kaakkaa Muttai  https://www.imdb.com/title/tt3973410/parentalg...
# 1  Bãhubali: The Beginning  https://www.imdb.com/title/tt2631186/parentalg...
# 2                Papanasam  https://www.imdb.com/title/tt4429128/parentalg...
# 3             Thani Oruvan  https://www.imdb.com/title/tt4987556/parentalg...
# 4         Kuttram Kadithal  https://www.imdb.com/title/tt4112208/parentalg...
#
#   Alcoholism Displayed  Year of Release
# 0                 None             2015
# 1                 Mild             2015
# 2                 None             2015
# 3             Moderate             2015
# 4                 None             2015

# %% [markdown]
# ### Creating values for each severity value<br><u>List:</u><ol><li>Severe: 3</li><li>Moderate: 2</li><li>Mild: 1</li><li>None: 0</li></ol>

# %%
alc_score = []
for x in g1['Alcoholism Displayed']:
    if(x == 'None'):
        alc_score.append(0)
    elif(x == 'Mild'):
        alc_score.append(1)
    elif(x == 'Moderate'):
        alc_score.append(2)
    elif(x== 'Severe'):
        alc_score.append(3)
    else:
        alc_score.append(0)
        
print(alc_score)
g1['Alcohol_Rating']=alc_score
(g1.head())
# Out:
# [0, 1, 0, 2, 0, 1, 2, 2, 2, 2, 1, 1, 0, 0, 2, 2, 3, 1, 0, 2, 1, 1, 2, 3, 1, 2, 1, 2, 3, 2, 3, 1, 1, 2, 2, 1, 0, 1, 1, 2, 1, 1, 1, 1, 2, 2, 0, 1, 2, 1, 1, 2, 1, 0, 0, 3, 2, 1, 1, 2, 0, 0, 1, 1, 3, 1, 1, 1, 2, 2, 2, 2, 1, 2, 1, 0, 1, 1, 2, 1, 0, 3, 0, 1, 1, 0, 2, 2, 1, 2, 2, 1, 2, 1, 2, 1, 2, 1, 1, 1, 1, 1, 0, 2, 1, 1, 1, 2, 0, 1, 2, 1, 2]
#                 Movie Name                                          IMDB Link  \
# 0           Kaakkaa Muttai  https://www.imdb.com/title/tt3973410/parentalg...
# 1  Bãhubali: The Beginning  https://www.imdb.com/title/tt2631186/parentalg...
# 2                Papanasam  https://www.imdb.com/title/tt4429128/parentalg...
# 3             Thani Oruvan  https://www.imdb.com/title/tt4987556/parentalg...
# 4         Kuttram Kadithal  https://www.imdb.com/title/tt4112208/parentalg...
#
#   Alcoholism Displayed  Year of Release  Alcohol_Rating
# 0                 None             2015               0
# 1                 Mild             2015               1
# 2                 None             2015               0
# 3             Moderate             2015               2
# 4                 None             2015               0

# %% [markdown]
# # VISUALIZATIONS

# %%
plt.figure(figsize=[9,9])
g1['Alcoholism Displayed'].value_counts().plot.pie()
plt.title("2015-2021 ALCOHOL AND SUBSTANCES DISPLAYED ON MOVIES")
plt.ylabel('')
plt.show()

# %%
g1_mean = g1.groupby(['Year of Release']).mean()
print(g1_mean)
# Out:
#                  Alcohol_Rating
# Year of Release
# 2015                   1.200000
# 2016                   1.571429
# 2017                   1.153846
# 2018                   1.235294
# 2019                   1.333333
# 2020                   1.208333
# 2021                   1.300000

# %%
plt.figure(figsize=[10,3])
#g1_mean['Alcohol_Rating'].value_counts().plot.barh()
plt.bar(g1_mean.index,g1_mean['Alcohol_Rating'])
plt.xlabel('Year of Release')
plt.ylabel('Severity')
plt.title("Display of Alc and Substances over the Years")
plt.show()

# %%
#Converting the data type of Revenue to float
g2 = g2.replace(',','', regex=True)
g2['Revenue in Crores'] = g2['Revenue in Crores'].astype(float)
print(g2.head())
g2.dtypes
# Out:
#     Unnamed: 0  Fiscal Year  Revenue in Crores % Change
# 12          12         2015           26188.00   11.91%
# 13          13         2016           25845.58   −6.76%
# 14          14         2017           26995.25    6.97%
# 15          15         2018           26797.96   −0.73%
# 16          16         2019           31157.83    8.39%
# Unnamed: 0             int64
# Fiscal Year            int64
# Revenue in Crores    float64
# % Change              object
# dtype: object

# %%
plt.figure(figsize=[10,5])
plt.plot(g2['Fiscal Year'], g2['Revenue in Crores'])
plt.xlabel('Year')
plt.ylabel('Revenue in Rupees (Crores)')
plt.title('Revenue collected in Tamil Nadu for Alcohol from 2015-2021')
plt.show()

# %%
plt.figure(figsize=[10,5])
plt.plot(g1_mean.index, g1_mean['Alcohol_Rating'])
plt.xlabel('Year')
plt.ylabel('Alcohol_Rating')
plt.title('Substances displayed in Top Tamil Movies from 2015-2021: Line Graph')
plt.show()

# plt.figure(figsize=[10,3])
# #g1_mean['Alcohol_Rating'].value_counts().plot.barh()
# plt.bar(g1_mean.index,g1_mean['Alcohol_Rating'])
# plt.xlabel('Year of Release')
# plt.ylabel('Severity')
# plt.title("Display of Alc and Substances over the Years")
# plt.show()

# %% [markdown]
# ### Creating a new data frame to join the data with common year values

# %%
new_df_year = g1_mean

# %%
rev_year = []
rev_mon = []
for x in g2['Fiscal Year']:
    rev_year.append(x)
for x in g2['Revenue in Crores']:
    rev_mon.append(x)
new_df_year['Year'] = rev_year
new_df_year['Revenue'] = rev_mon
print(new_df_year)
g1['Alcohol_Rating']=alc_score
# Out:
#                  Alcohol_Rating  Year   Revenue   Crime
# Year of Release
# 2015                   1.200000  2015  26188.00  254604
# 2016                   1.571429  2016  25845.58  467369
# 2017                   1.153846  2017  26995.25  420876
# 2018                   1.235294  2018  26797.96  499188
# 2019                   1.333333  2019  31157.83  455094
# 2020                   1.208333  2020  33811.14  377681
# 2021                   1.300000  2021  33133.24       0

# %%
plt.rcParams["figure.figsize"] = (12,4)
ax = new_df_year.plot(kind = 'line', x = 'Year',y = 'Alcohol_Rating', color = 'Blue',linewidth = 2)
 
ax2 = new_df_year.plot(kind = 'line', x = 'Year',y = 'Revenue', secondary_y = True, color = 'Red',  linewidth = 2,ax = ax)


plt.title("Comparison")
ax.set_xlabel('Year')
ax.set_ylabel('Movies Displaying Alcohol and Substances', color = "b")
ax2.set_ylabel('Alcohol Consumed - Revenue (Rs)', color = 'r')
 
plt.savefig("result1.jpg")
plt.show()

# %%
#df_crime.head()
crime_list = []
for x in df_crime['Crime']:
    crime_list.append(x)

new_df_year['Crime'] = crime_list
new_df_year = new_df_year.head(6)

print(new_df_year)
# Out:
#                  Alcohol_Rating  Year   Revenue   Crime
# Year of Release
# 2015                   1.200000  2015  26188.00  254604
# 2016                   1.571429  2016  25845.58  467369
# 2017                   1.153846  2017  26995.25  420876
# 2018                   1.235294  2018  26797.96  499188
# 2019                   1.333333  2019  31157.83  455094
# 2020                   1.208333  2020  33811.14  377681

# %%
plt.rcParams["figure.figsize"] = (12,4)
ax = new_df_year.plot(kind = 'line', x = 'Year',y = 'Alcohol_Rating', color = 'Blue',linewidth = 2)
 
ax2 = new_df_year.plot(kind = 'line', x = 'Year',y = 'Crime', secondary_y = True, color = 'Red',  linewidth = 2,ax = ax)


plt.title("Comparison of Crime Rate and Movie Alcohol Displayed")
ax.set_xlabel('Year')
ax.set_ylabel('Movies Displaying Alcohol and Substances', color = "b")
ax2.set_ylabel('Crime', color = 'r')
plt.savefig("result2.jpg")
plt.show()

# %%
new_df_tail = new_df_year_crime.tail()
plt.rcParams["figure.figsize"] = (12,4)
ax = new_df_tail.plot(kind = 'line', x = 'Year',y = 'Revenue',  linestyle='dashed', marker='o',color = 'Green',linewidth = 2)
 
ax2 = new_df_tail.plot(kind = 'line', x = 'Year',y = 'Crime', secondary_y = True, color = 'Blue',  linewidth = 2,ax = ax)


plt.title("Comparison of Alcohol Revenue and Crime Rates in Tamil Nadu")
ax.set_xlabel('Year')
ax.set_ylabel('Revenue', color = "g")
ax2.set_ylabel('Crime', color = 'b')
plt.savefig("result3.jpg")
plt.show()

# %%
import requests
from bs4 import BeautifulSoup
import re
import string
import numpy as np

def url_violence_imdb(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    text = [p.text for p in soup.find('section', id = "advisory-violence")]
    req = text[3]
    req = re.sub('\[.*?\]', '', req)
    req = re.sub('[%s]' % re.escape(string.punctuation), '', req)
    req = re.sub('\s+', ' ', req)
    alc_cont = ''
    alc_cont = req.split(' ').pop(1)
    if(alc_cont == 'Be'):
        alc_cont = 'Unrated'
    
    #print(alc_cont)
    return alc_cont
    #return text
#url_violence_imdb('https://www.imdb.com/title/tt3973410/parentalguide')
crime_list = []
df1_link = pd.read_csv(r'C:\Users\Roshni\OneDrive\Desktop\Roshni\Projects\Alcohol-Movies\movies_alc.csv')
for x in df1_link['IMDB Link']:
    y = url_violence_imdb(x)
    crime_list.append(y)
print(crime_list)
# Out:
# ['Mild', 'Moderate', 'Moderate', 'Moderate', 'Mild', 'Unrated', 'Moderate', 'Unrated', 'Unrated', 'Moderate', 'Unrated', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Severe', 'Mild', 'Mild', 'None', 'Mild', 'None', 'Moderate', 'Mild', 'Mild', 'Moderate', 'Severe', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Severe', 'None', 'Severe', 'Severe', 'Mild', 'Moderate', 'Moderate', 'Severe', 'Moderate', 'Severe', 'Mild', 'Severe', 'Moderate', 'Unrated', 'Mild', 'Severe', 'Unrated', 'Mild', 'Unrated', 'Moderate', 'Mild', 'Moderate', 'Unrated', 'Mild', 'Unrated', 'Mild', 'Unrated', 'Unrated', 'Moderate', 'Moderate', 'Unrated', 'Unrated', 'Severe', 'Moderate', 'None', 'Severe', 'Unrated', 'Moderate', 'Moderate', 'Severe', 'Moderate', 'None', 'Moderate', 'None', 'Moderate', 'Unrated', 'Moderate', 'Unrated', 'Severe', 'Mild', 'None', 'Moderate', 'Mild', 'Mild', 'Severe', 'Moderate', 'Mild', 'None', 'None', 'Severe', 'Mild', 'Severe', 'Mild', 'Mild', 'Mild', 'Moderate', 'Severe', 'Moderate', 'Severe', 'Moderate', 'Moderate', 'None', 'Mild', 'Severe', 'Severe', 'Moderate', 'Mild', 'None', 'Moderate', 'Mild', 'Moderate', 'Moderate', 'Unrated', 'Moderate', 'Moderate', '', 'Moderate', 'Moderate', 'None', 'Moderate', 'None', 'Mild', 'Severe', 'Mild', 'Moderate', 'Mild', 'Moderate', 'Mild', 'Moderate', 'Severe', 'Unrated', 'Unrated', 'Moderate', 'Moderate', 'Unrated', 'Mild', 'Unrated', 'Unrated', 'Unrated', 'Mild', 'Unrated', 'Unrated', 'Mild', 'Severe', 'Moderate', 'Unrated']

# %%
df1_link['Violence'] = crime_list
violence_score = []
for x in df1_link['Violence']:
    if(x == 'None'):
        violence_score.append(0)
    elif(x == 'Mild'):
        violence_score.append(1)
    elif(x == 'Moderate'):
        violence_score.append(2)
    elif(x== 'Severe'):
        violence_score.append(3)
    else:
        violence_score.append(0)
        
df1_link['Violence Rate']=violence_score
df1_link.head(150)
# Out:
#                   Movie Name  \
# 0             Kaakkaa Muttai
# 1    Bãhubali: The Beginning
# 2                  Papanasam
# 3               Thani Oruvan
# 4           Kuttram Kadithal
# ..                       ...
# 141             Anbirkiniyal
# 142                    Teddy
# 143    Nenjam Marappathillai
# 144           Kodiyil Oruvan
# 145              Sabhaapathy
#
#                                              IMDB Link Alcoholism Displayed  \
# 0    https://www.imdb.com/title/tt3973410/parentalg...                 None
# 1    https://www.imdb.com/title/tt2631186/parentalg...                 Mild
# 2    https://www.imdb.com/title/tt4429128/parentalg...                 None
# 3    https://www.imdb.com/title/tt4987556/parentalg...             Moderate
# 4    https://www.imdb.com/title/tt4112208/parentalg...                 None
# ..                                                 ...                  ...
# 141  https://www.imdb.com/title/tt14092076/parental...              Unrated
# 142  https://www.imdb.com/title/tt10888824/parental...                 Mild
# 143  https://www.imdb.com/title/tt5985720/parentalg...             Moderate
# 144  https://www.imdb.com/title/tt13451738/parental...              Unrated
# 145  https://www.imdb.com/title/tt13885642/parental...              Unrated
#
#      Year of Release  Violence  Violence Rate
# 0               2015      Mild              1
# 1               2015  Moderate              2
# 2               2015  Moderate              2
# 3               2015  Moderate              2
# 4               2015      Mild              1
# ..               ...       ...            ...
# 141             2021   Unrated              0
# 142             2021      Mild              1
# 143             2021    Severe              3
# 144             2021  Moderate              2
# 145             2021   Unrated              0
#
# [146 rows x 6 columns]

# %%
df_viol_mean = df1_link.groupby(['Year of Release']).mean()
print(df_viol_mean.head(10))

plt.figure(figsize=[10,5])
plt.plot(df_viol_mean.index, df_viol_mean['Violence Rate'],color = 'Green')
plt.xlabel('Year')
plt.ylabel('Violence Rate')
plt.title('Violence in Movies from 2015-2021: Line Graph')
plt.show()
# Out:
#                  Violence Rate
# Year of Release
# 2015                  1.333333
# 2016                  1.800000
# 2017                  1.000000
# 2018                  1.450000
# 2019                  1.666667
# 2020                  1.423077
# 2021                  1.000000

# %%
violence_rate_list = []
for x in df_viol_mean['Violence Rate']:
    violence_rate_list.append(x)
#print(new_df_tail.head(10))
#print(df_viol_mean.head(10))

df_viol_up = df_viol_mean.head(6)
df_viol_up = df_viol_up.tail(5)
# print(df_viol_up)
# print(violence_rate_list)
violence_rate_list_fin = violence_rate_list[1:-1]
print(violence_rate_list_fin)
df_viol_up['Movie Violence'] = violence_rate_list_fin
# df_viol_up.head()
#new_df_tail['Movie Violence'] = violence_rate_list
#new_df_tail.head()
# Out:
# [1.8, 1.0, 1.45, 1.6666666666666667, 1.4230769230769231]

# %%
df_tot = new_df_tail 
df_tot['Movie Violence'] = violence_rate_list_fin
print(df_tot.head())
# Out:
#                  Alcohol_Rating  Year   Revenue   Crime  Movie Violence
# Year of Release
# 2016                   1.571429  2016  25845.58  467369        1.800000
# 2017                   1.153846  2017  26995.25  420876        1.000000
# 2018                   1.235294  2018  26797.96  499188        1.450000
# 2019                   1.333333  2019  31157.83  455094        1.666667
# 2020                   1.208333  2020  33811.14  377681        1.423077
# C:\Users\Roshni\AppData\Local\Temp/ipykernel_2572/1824043057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tot['Movie Violence'] = violence_rate_list_fin

# %%
plt.rcParams["figure.figsize"] = (12,4)
ax = df_tot.plot(kind = 'line', x = 'Year',y = 'Movie Violence',  linestyle='dashed', marker='o',color = 'Green',linewidth = 3)
 
ax2 = df_tot.plot(kind = 'line', x = 'Year',y = 'Crime', secondary_y = True,  linestyle='dashed', marker='o', color = 'Blue',  linewidth = 3,ax = ax)


plt.title("Comparison between Violence in Movies and Crime Rates in TN")
ax.set_xlabel('Year')
ax.set_ylabel('Movie Violence Rating', color = "g")
ax2.set_ylabel('Crime', color = 'b')
plt.savefig("result4.jpg")
plt.show()

# %% [markdown]
# ### <br><span style="color:green"><b><h3>RESULT:</h3></b><br><br> Graphs made: <br> 1. Crime in TN vs Violence in Movies <br> 2. Crime in TN vs Alcoholism <br> 3. Severity of displaying alcohol in movies vs Alcoholism in TN </span>
#
# ### <b>NOTE:</b><br>There are several factors to be considered such as laws, economy, tourism which have been ignored for the project. I have only scraped data for the alcohol revenue in Tamil Nadu and IMDB rating for Alcohol, Smoking and Substance abuse.<br>This project only takes into account a very small dataset. Clear results can only be seen upon taking into account larger datasets and then analyzing.
#
# ### This project has been created to understand <br> <ul><li>Web Scraping via BeautifulSoup</li><li>Pandas</li><li>Matplotlib</li></ul>
